# %% [markdown]
# # Tabel No 1

# %%
import pandas as pd

#memuat data
data_kanker = pd.read_csv("breast_cancer.csv")
data_kanker
# Out:
#          age  menopause tumor-size inv-nodes node-caps deg-malig   breast  \
# 0    '40-49'  'premeno'    '15-19'     '0-2'     'yes'       '3'  'right'
# 1    '50-59'     'ge40'    '15-19'     '0-2'      'no'       '1'  'right'
# 2    '50-59'     'ge40'    '35-39'     '0-2'      'no'       '2'   'left'
# 3    '40-49'  'premeno'    '35-39'     '0-2'     'yes'       '3'  'right'
# 4    '40-49'  'premeno'    '30-34'     '3-5'     'yes'       '2'   'left'
# ..       ...        ...        ...       ...       ...       ...      ...
# 272  '50-59'     'ge40'    '30-34'     '6-8'     'yes'       '2'   'left'
# 273  '50-59'  'premeno'    '25-29'     '3-5'     'yes'       '2'   'left'
# 274  '30-39'  'premeno'    '30-34'     '6-8'     'yes'       '2'  'right'
# 275  '50-59'  'premeno'    '15-19'     '0-2'      'no'       '2'  'right'
# 276  '50-59'     'ge40'    '40-44'     '0-2'      'no'       '3'   'left'
#
#     breast-quad irradiat                   Class
# ...

# %% [markdown]
# # Eksplorasi dan Jawablah Pertanyaan

# %% [markdown]
# Berapa banyak pasien yang berumur 50-59 tahun dengan derajat keganasan kanker payudara sebesar 2?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['age'] == "'50-59'") & (data_kanker['deg-malig'] == "'2'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang berumur 50-59 tahun dengan derajat keganasan kanker payudara sebesar 2 adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang berumur 50-59 tahun dengan derajat keganasan kanker payudara sebesar 2 adalah 39

# %% [markdown]
# Berapa banyak pasien dengan ukuran tumor 0-4 (mm) dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps)?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['tumor-size'] == "'0-4'") & (data_kanker['node-caps'] == "'no'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien dengan ukuran tumor 0-4 (mm) dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps) adalah", jumlah_pasien)
# Out:
# Jumlah pasien dengan ukuran tumor 0-4 (mm) dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps) adalah 8

# %% [markdown]
# Berapa banyak pasien dengan tumor yang melakukan terapi radiasi dengan derajat keganasan kanker sebesar 2 dan 3?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['deg-malig'].isin([2,3])) & (data_kanker['irradiat'] == "'yes'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien dengan tumor yang melakukan terapi radiasi dengan derajat keganasan kanker sebesar 2 dan 3 adalah", jumlah_pasien)
# Out:
# Jumlah pasien dengan tumor yang melakukan terapi radiasi dengan derajat keganasan kanker sebesar 2 dan 3 adalah 0

# %% [markdown]
# Berapa banyak pasien yang memiliki tumor yang terletak di sebelah kanan dan kiri serta tepatnya pada kuadran pusat?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['breast-quad'] == "'central'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang memiliki tumor yang terletak di sebelah kanan dan kiri serta tepatnya pada kuadran pusat adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang memiliki tumor yang terletak di sebelah kanan dan kiri serta tepatnya pada kuadran pusat adalah 21

# %% [markdown]
# Berapa banyak pasien yang sedang premenopause dengan kelenjar getah bening yang mengandung kanker payudara pada range 6-8?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['menopause'] == "'premeno'") & (data_kanker['inv-nodes'] == "'6-8'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang sedang premenopause dengan kelenjar getah bening yang mengandung kanker payudara pada range 6-8 adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang sedang premenopause dengan kelenjar getah bening yang mengandung kanker payudara pada range 6-8 adalah 7

# %% [markdown]
# Berapa banyak pasien yang telah melakukan terapi radiasi, tetapi masih ada kemungkinan terjadi kekambuhan ulang?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['irradiat'] == "'yes'") & (data_kanker['Class'] == "'recurrence-events'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang telah melakukan terapi radiasi, tetapi masih ada kemungkinan terjadi kekambuhan ulang adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang telah melakukan terapi radiasi, tetapi masih ada kemungkinan terjadi kekambuhan ulang adalah 30

# %% [markdown]
# Berapa banyak pasien yang masih berumur 30-39 tahun dengan kondisi kelenjar getah bening telah menembus kapsul dan sekitarnya (node-caps)?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['age'] == "'30-39'") & (data_kanker['node-caps'] == "'yes'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang masih berumur 30-39 tahun dengan kondisi kelenjar getah bening telah menembus kapsul dan sekitarnya (node-caps) adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang masih berumur 30-39 tahun dengan kondisi kelenjar getah bening telah menembus kapsul dan sekitarnya (node-caps) adalah 8

# %% [markdown]
# Berapa banyak pasien yang menopause di atas umur 40 tahun, tetapi tidak melakukan terapi radiasi?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['menopause'] == "'ge40'") & (data_kanker['irradiat'] == "'no'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien yang menopause di atas umur 40 tahun, tetapi tidak melakukan terapi radiasi adalah", jumlah_pasien)
# Out:
# Jumlah pasien yang menopause di atas umur 40 tahun, tetapi tidak melakukan terapi radiasi adalah 99

# %% [markdown]
# Berapa banyak pasien dengan ukuran tumor sebesar 50-54 (mm) dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatik sebesar 0-2
# (mm)?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['tumor-size'] == "'50-54'") & (data_kanker['inv-nodes'] == "'0-2'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien dengan ukuran tumor sebesar 50-54 (mm) dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatik sebesar 0-2 (mm) adalah", jumlah_pasien)
# Out:
# Jumlah pasien dengan ukuran tumor sebesar 50-54 (mm) dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatik sebesar 0-2 (mm) adalah 7

# %% [markdown]
# Berapa banyak pasien dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatic sebesar 15-17 (mm) dan dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps)?

# %%
#filter data dari dataset yang diminta
filter_data_kanker = data_kanker[(data_kanker['tumor-size'] == "'15-19'") & (data_kanker['node-caps'] == "'no'")]

#menghitung hasil dataset
jumlah_pasien = len(filter_data_kanker)
print("Jumlah pasien dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatic sebesar 15-17 (mm) dan dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps) adalah", jumlah_pasien)
# Out:
# Jumlah pasien dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatic sebesar 15-17 (mm) dan dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps) adalah 25

# %% [markdown]
# # Tabel no 2

# %%
import pandas as pd

#memuat data
ukuran_tumor_ganjil = pd.read_csv("df1tumor_size_odd.csv")
ukuran_tumor_genap = pd.read_csv("df2tumor_size_even.csv")
kuadran_payudara_ganjil = pd.read_csv("df1breastquad_odd.csv")
kuadran_payudara_genap = pd.read_csv("df2breastquad_even.csv")
print("Ukuran Tumor Ganjil\n", ukuran_tumor_ganjil, 
      "\nUkuran Tumor Genap\n", ukuran_tumor_genap, 
      "\nKuadran Payudara Ganjil\n",kuadran_payudara_ganjil, 
      "\nKuadran Payudara Genap\n", kuadran_payudara_genap)
# Out:
# Ukuran Tumor Ganjil
#       PatientID tumor-size
# 0            1    '15-19'
# 1            3    '35-39'
# 2            5    '30-34'
# 3            7    '40-44'
# 4            9      '0-4'
# ..         ...        ...
# 115        265    '20-24'
# 116        269    '35-39'
# 117        271    '20-24'
# 118        275    '30-34'
# 119        277    '40-44'
#
# [120 rows x 2 columns]
# Ukuran Tumor Genap
#       PatientID tumor-size
# 0            4    '35-39'
# 1            6    '25-29'
# 2            8    '10-14'
# 3           12    '15-19'
# 4           14    '25-29'
# ..         ...        ...
# 113        268    '25-29'
# 114        270    '30-34'
# 115        272    '15-19'
# 116        274    '25-29'
# 117        276    '15-19'
#
# [118 rows x 2 columns]
# Kuadran Payudara Ganjil
#       PatientID  breast-quad
# 0            1    'left_up'
# 1            3   'left_low'
# 2            7    'left_up'
# 3            9  'right_low'
# 4           11   'left_low'
# ...

# %% [markdown]
# # Penggabungan Data Menggunakan Inner Join, Left Join, Right Join, dan Outer Join Dan Jawablah Pertanyaan

# %%
import pandas as pd

# Baca data dari file CSV
tumor_size_ganjil = pd.read_csv('df1tumor_size_odd.csv')
tumor_size_genap = pd.read_csv('df2tumor_size_even.csv')
breast_quad_ganjil = pd.read_csv('df1breastquad_odd.csv')
breast_quad_genap = pd.read_csv('df2breastquad_even.csv')

# Inner Join
inner_join_ganjil = pd.merge(tumor_size_ganjil, breast_quad_ganjil, on='PatientID', how='inner')
print("Hasil Inner Join untuk ganjil:")
print(inner_join_ganjil)
inner_join_genap = pd.merge(tumor_size_genap, breast_quad_genap, on='PatientID', how='inner')
print("Hasil Inner Join untuk genap:")
print(inner_join_genap)

# Left Join
left_join_ganjil = pd.merge(tumor_size_ganjil, breast_quad_ganjil, on='PatientID', how='left')
print("Hasil Left Join untuk ganjil:")
print(left_join_ganjil)
left_join_genap = pd.merge(tumor_size_genap, breast_quad_genap, on='PatientID', how='left')
print("Hasil Left Join untuk genap:")
print(left_join_genap)

# Right Join
right_join_ganjil = pd.merge(tumor_size_ganjil, breast_quad_ganjil, on='PatientID', how='right')
print("Hasil Right Join untuk ganjil:")
print(right_join_ganjil)
right_join_genap = pd.merge(tumor_size_genap, breast_quad_genap, on='PatientID', how='right')
print("Hasil Right Join untuk genap:")
print(right_join_genap)

# Outer Join
outer_join_ganjil = pd.merge(tumor_size_ganjil, breast_quad_ganjil, on='PatientID', how='outer')
print("Hasil Outer Join untuk ganjil:")
print(outer_join_ganjil)
outer_join_genap = pd.merge(tumor_size_genap, breast_quad_genap, on='PatientID', how='outer')
print("Hasil Outer Join untuk genap:")
print(outer_join_genap)
# Out:
# Hasil Inner Join untuk ganjil:
#      PatientID tumor-size  breast-quad
# 0            1    '15-19'    'left_up'
# 1            3    '35-39'   'left_low'
# 2            7    '40-44'    'left_up'
# 3            9      '0-4'  'right_low'
# 4           11    '25-29'   'left_low'
# ..         ...        ...          ...
# 96         265    '20-24'   'left_low'
# 97         269    '35-39'   'right_up'
# 98         271    '20-24'   'right_up'
# 99         275    '30-34'   'right_up'
# 100        277    '40-44'   'right_up'
#
# [101 rows x 3 columns]
# Hasil Inner Join untuk genap:
#      PatientID tumor-size breast-quad
# 0            6    '25-29'   'left_up'
# 1            8    '10-14'   'left_up'
# 2           12    '15-19'   'left_up'
# 3           14    '25-29'   'left_up'
# 4           16    '20-24'   'central'
# ..         ...        ...         ...
# 97         264    '20-24'   'left_up'
# 98         266    '35-39'  'left_low'
# 99         268    '25-29'   'left_up'
# ...

# %% [markdown]
# Berapa banyak record pasien yang memiliki nilai atribut ukuran tumor dan nilai kuadran kanker payudara secara lengkap keduanya?

# %%
# Jumlah rekord dengan nilai atribut ukuran tumor dan kuadran kanker payudara
jumlah_record_lengkap_ganjil = inner_join_ganjil.shape[0]
print("Jumlah record pasien yang memiliki nilai atribut ukuran tumor dan kuadran kanker payudara (Ganjil):" , jumlah_record_lengkap_ganjil, "\n")
jumlah_record_lengkap_genap = inner_join_genap.shape[0]
print("Jumlah record pasien yang memiliki nilai atribut ukuran tumor dan kuadran kanker payudara (Genap):", jumlah_record_lengkap_genap, "\n")
total_semuanya = jumlah_record_lengkap_ganjil + jumlah_record_lengkap_genap
print("Jumlah record semuanya:", total_semuanya, "\n")
# Out:
# Jumlah record pasien yang memiliki nilai atribut ukuran tumor dan kuadran kanker payudara (Ganjil): 101
#
# Jumlah record pasien yang memiliki nilai atribut ukuran tumor dan kuadran kanker payudara (Genap): 102
#
# Jumlah record semuanya: 203

# %% [markdown]
# Berapa banyak record pasien yang memiliki nilai atribut ukuran tumor, tetapi tidak memiliki nilai kuadran kanker payudara? serta berapa banyak record nilai atribut kuadran kanker payudara yang NaN tersebut?

# %%
# Jumlah rekord dengan nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Ganjil)
jumlah_record_ukuran_tumor_tanpa_kuadran_ganjil = left_join_ganjil[left_join_ganjil['breast-quad'].isna()].shape[0]
print("Jumlah rekord pasien yang memiliki nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Ganjil):", jumlah_record_ukuran_tumor_tanpa_kuadran_ganjil, "\n")

# Jumlah rekord dengan nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Genap)
jumlah_record_ukuran_tumor_tanpa_kuadran_genap = left_join_genap[left_join_genap['breast-quad'].isna()].shape[0]
print("Jumlah rekord pasien yang memiliki nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Genap):", jumlah_record_ukuran_tumor_tanpa_kuadran_genap, "\n")

# hitung semuanya
total_semuanya_record = jumlah_record_ukuran_tumor_tanpa_kuadran_ganjil  + jumlah_record_ukuran_tumor_tanpa_kuadran_genap
print("Total semuanya:", total_semuanya_record, "\n")

# Jumlah nilai atribut kuadran kanker payudara yang NaN (Ganjil)
jumlah_nan_kuadran_ganjil = left_join_ganjil['breast-quad'].isna().sum()
print("Jumlah record nilai atribut kuadran kanker payudara yang NaN (Ganjil):", jumlah_nan_kuadran_ganjil, "\n")

# Jumlah nilai atribut kuadran kanker payudara yang NaN (Ganjil)
jumlah_nan_kuadran_genap = left_join_genap['breast-quad'].isna().sum()
print("Jumlah record nilai atribut kuadran kanker payudara yang NaN (Genap):", jumlah_nan_kuadran_genap, "\n")

# hitung semuanya
total_semuanya_nan = jumlah_nan_kuadran_ganjil + jumlah_nan_kuadran_genap
print("Total semuanya:", total_semuanya_nan, "\n")
# Out:
# Jumlah rekord pasien yang memiliki nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Ganjil): 19
#
# Jumlah rekord pasien yang memiliki nilai atribut ukuran tumor tetapi tidak memiliki nilai kuadran kanker payudara (Genap): 16
#
# Total semuanya: 35
#
# Jumlah record nilai atribut kuadran kanker payudara yang NaN (Ganjil): 19
#
# Jumlah record nilai atribut kuadran kanker payudara yang NaN (Genap): 16
#
# Total semuanya: 35

# %% [markdown]
# Berapa banyak record pasien yang tidak memiliki nilai atribut ukuran tumor, tetapi memiliki nilai kuadran kanker payudara? serta berapa banyak record nilai atribut ukuran tumor yang NaN tersebut?

# %%
# Hitung jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (Ganjil)
pasien_tanpa_tumor_ganjil = right_join_ganjil[right_join_ganjil['tumor-size'].isna()]
jumlah_pasien_tanpa_tumor_ganjil = len(pasien_tanpa_tumor_ganjil)
print("Jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (dengan right join) untuk ganjil:", jumlah_pasien_tanpa_tumor_ganjil, "\n")

# Hitung jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (Genap)
pasien_tanpa_tumor_genap = right_join_genap[right_join_genap['tumor-size'].isna()]
jumlah_pasien_tanpa_tumor_genap = len(pasien_tanpa_tumor_genap)
print("Jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (dengan right join) untuk genap:", jumlah_pasien_tanpa_tumor_genap, "\n")

# hitung semuanya
total_semuanya_record = jumlah_pasien_tanpa_tumor_ganjil + jumlah_pasien_tanpa_tumor_genap
print("Total semuanya:", total_semuanya_record, "\n")

# Hitung jumlah record dengan nilai atribut ukuran tumor yang NaN (Ganjil)
jumlah_tumor_nan_ganjil = right_join_ganjil['tumor-size'].isna().sum()
print("Jumlah record dengan nilai atribut ukuran tumor yang NaN (dengan right join) untuk ganjil:", jumlah_tumor_nan_ganjil, "\n")

# Hitung jumlah record dengan nilai atribut ukuran tumor yang NaN (Genap)
jumlah_tumor_nan_genap = right_join_genap['tumor-size'].isna().sum()
print("Jumlah record dengan nilai atribut ukuran tumor yang NaN (dengan right join) untuk genap:", jumlah_tumor_nan_genap, "\n")

# hitung semuanya
total_semuanya_nan = jumlah_tumor_nan_ganjil + jumlah_tumor_nan_genap
print("Total semuanya:", total_semuanya_nan, "\n")
# Out:
# Jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (dengan right join) untuk ganjil: 18
#
# Jumlah record pasien yang tidak memiliki nilai atribut ukuran tumor tetapi memiliki nilai kuadran kanker payudara (dengan right join) untuk genap: 16
#
# Total semuanya: 34
#
# Jumlah record dengan nilai atribut ukuran tumor yang NaN (dengan right join) untuk ganjil: 18
#
# Jumlah record dengan nilai atribut ukuran tumor yang NaN (dengan right join) untuk genap: 16
#
# Total semuanya: 34

# %% [markdown]
# Jika menggunakan Outer Join, Berapa banyak record pasien yang NaN pada masing-masing atribut, baik pada atribut ukuran tumor maupun kuadran kanker payudara?

# %%
# Jumlah rekord dengan nilai atribut ukuran tumor dan kuadran kanker payudara yang NaN (Ganjil)
jumlah_nan_ukuran_tumor_outer_ganjil = outer_join_ganjil['tumor-size'].isna().sum()
print("Jumlah rekord dengan nilai atribut ukuran tumor yang NaN (Ganjil):", jumlah_nan_ukuran_tumor_outer_ganjil, "\n")
jumlah_nan_kuadran_outer_ganjil = outer_join_ganjil['breast-quad'].isna().sum()
print("Jumlah rekord dengan nilai atribut kuadran kanker payudara yang NaN (Ganjil):", jumlah_nan_kuadran_outer_ganjil, "\n")

# Jumlah rekord dengan nilai atribut ukuran tumor dan kuadran kanker payudara yang NaN (Genap)
jumlah_nan_ukuran_tumor_outer_genap = outer_join_genap['tumor-size'].isna().sum()
print("Jumlah rekord dengan nilai atribut ukuran tumor yang NaN (Genap):", jumlah_nan_ukuran_tumor_outer_genap, "\n")
jumlah_nan_kuadran_outer_genap = outer_join_genap['breast-quad'].isna().sum()
print("Jumlah rekord dengan nilai atribut kuadran kanker payudara yang NaN (Genap):", jumlah_nan_kuadran_outer_genap, "\n")
# Out:
# Jumlah rekord dengan nilai atribut ukuran tumor yang NaN (Ganjil): 18
#
# Jumlah rekord dengan nilai atribut kuadran kanker payudara yang NaN (Ganjil): 19
#
# Jumlah rekord dengan nilai atribut ukuran tumor yang NaN (Genap): 16
#
# Jumlah rekord dengan nilai atribut kuadran kanker payudara yang NaN (Genap): 16

# %% [markdown]
# # Tabel no 3

# %%
import pandas as pd

# Baca dataset hepatitis
data_hepatitis = pd.read_csv('Hepatitis.csv', header = 1, index_col = 0)
data_hepatitis
# Out:
#      Age  Sex Steroid  Antivirals Fatique Malaise Anorexia Liver Big  \
# 1     30    2       1           2       2       2        2         1
# 2     50    1       1           2       1       2        2         1
# 3     78    1       2           2       1       2        2         2
# 4     31    1       ?           1       2       2        2         2
# 5     34    1       2           2       2       2        2         2
# ..   ...  ...     ...         ...     ...     ...      ...       ...
# 151   46    1       2           2       1       1        1         2
# 152   44    1       2           2       1       2        2         2
# 153   61    1       1           2       1       1        2         1
# 154   53    2       1           2       1       2        2         2
# 155   43    1       2           2       1       2        2         2
#
#     Liver Firm Spleen Palpable Speiders Ascites Varices Bilirubin  \
# 1            2               2        2       2       2         1
# ...

# %% [markdown]
# # Transformasi Data: Duplikasi Data, Missing Values, dan Imputasi Missing Values

# %% [markdown]
# Lakukan pemeriksaan apakah terdapat duplikasi data (row) pada dataset hepatitis

# %%
# Baca dataset hepatitis
data_hepatitis = pd.read_csv('Hepatitis.csv', header = 1, index_col = 0)

# Cek duplikasi data dan menjumlah data duplikatnya 
baris_duplikat = data_hepatitis[data_hepatitis.duplicated()]
jumlah_duplikat = data_hepatitis.duplicated().sum()

# Jika terdapat duplikasi data, tampilkan informasi duplikasi dan jumlah datanya
if not baris_duplikat.empty:
    print("Terdapat duplikasi data pada data hepatitis adalah :", jumlah_duplikat)
    print(baris_duplikat)
else:
    print("Tidak ada duplikasi data pada data hepatitis adalah :", jumlah_duplikat)
# Out:
# Tidak ada duplikasi data pada data hepatitis adalah : 0

# %% [markdown]
# Lakukan analisis deskriptif berapa banyak atribut yang memiliki missing values

# %%
import pandas as pd

# Baca dataset hepatitis
data_hepatitis = pd.read_csv('Hepatitis.csv', header=1, index_col=0)

def ganti_pertanyaan_tanda_dengan_tidak_ada(a):
    if a == '?':
        return None
    else:
        return a

# Buat salinan data asli
update_data_hepatitis = data_hepatitis.copy()

# Terapkan fungsi penggantian pada setiap kolom
for kolom in update_data_hepatitis.columns:
    update_data_hepatitis[kolom] = update_data_hepatitis[kolom].apply(ganti_pertanyaan_tanda_dengan_tidak_ada)

# Informasi tentang dataset
info_data_hepatitis = update_data_hepatitis.info()
print("\nInformasi dataset hepatitis adalah :", info_data_hepatitis)

# Jumlah nilai yang hilang (NaN) dalam setiap kolom
jumlah_null_per_kolom = update_data_hepatitis.isna().sum()
print("\nJumlah nilai yang hilang dalam setiap kolom adalah :")
print(jumlah_null_per_kolom)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 1 to 155
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              155 non-null    int64
#  1   Sex              155 non-null    int64
#  2   Steroid          154 non-null    object
#  3   Antivirals       155 non-null    int64
#  4   Fatique          154 non-null    object
#  5   Malaise          154 non-null    object
#  6   Anorexia         154 non-null    object
#  7   Liver Big        145 non-null    object
#  8   Liver Firm       144 non-null    object
#  9   Spleen Palpable  150 non-null    object
#  10  Speiders         150 non-null    object
#  11  Ascites          150 non-null    object
#  12  Varices          150 non-null    object
#  13  Bilirubin        149 non-null    object
#  14  Alk Phosphate    126 non-null    object
#  15  SGOT             151 non-null    object
#  16  Albumin          139 non-null    object
# ...

# %% [markdown]
# Lakukan imputasi missing values dengan berbagai teknik yang efektif dan baik untuk mengisi atribut-atribut yang NaN, misalnya menggunakan mean, median, modus, clustering, regression, maupun metode taksiran dan prediksi lainnya

# %%
# memuat library
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
# Baca dataset hepatitis
data_hepatitis = pd.read_csv('Hepatitis.csv', header=1, index_col=0)

# menggantikan '?' dengan NaN
data_hepatitis.replace('?', np.nan, inplace=True)
data_hepatitis.dropna(inplace=True)

imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# Kolom-kolom numerik
numeric_cols = ['Age', 'Bilirubin', 'Alk Phosphate', 'SGOT', 'Albumin', 'Protime']

# mean
data_hepatitis[numeric_cols] = imputer_mean.fit_transform(data_hepatitis[numeric_cols])
print('Hasil data hepatitis mean\n', data_hepatitis[numeric_cols])

# median
data_hepatitis[numeric_cols] = imputer_median.fit_transform(data_hepatitis[numeric_cols])
print('\nHasil data hepatitis median\n', data_hepatitis[numeric_cols])

# modus
data_hepatitis[numeric_cols] = imputer_modus.fit_transform(data_hepatitis[numeric_cols])
print('\nHasil data hepatitis modus\n', data_hepatitis[numeric_cols])

# Imputasi dengan clustering, anda perlu memilih atribut yang sesuai untuk clustering
clustering_data_hepatitis = data_hepatitis[['Age', 'Bilirubin']]
kmeans = KMeans(n_clusters=3, random_state=0)
data_hepatitis['Cluster_Labels'] = kmeans.fit_predict(clustering_data_hepatitis)
print('Hasil clustering\n', data_hepatitis['Cluster_Labels'])
data_hepatitis['Alk Phosphate'] = data_hepatitis.groupby('Cluster_Labels')['Alk Phosphate'].transform(lambda x: x.fillna(x.mean()))
print('\nHasil kolom Alk Phosphate yang sudah diimputasi\n', data_hepatitis['Alk Phosphate'])

# Imputasi dengan regresi, anda perlu mengganti kolom target dan atribut yang digunakan untuk regresi sesuai kebutuhan Anda
regression_data_hepatitis = data_hepatitis[['Age', 'Bilirubin', 'Albumin']]
target_column = 'Alk Phosphate'
regressor = LinearRegression()
for target_value in data_hepatitis[target_column].unique():
    subset = data_hepatitis[data_hepatitis[target_column] == target_value]
    subset_X = subset[['Age', 'Bilirubin', 'Albumin']].dropna()
    subset_y = subset[subset[target_column].notna()][target_column]
    regressor.fit(subset_X, subset_y)
    mask = data_hepatitis[target_column] == target_value
    data_hepatitis.loc[mask, target_column] = regressor.predict(data_hepatitis[mask][['Age', 'Bilirubin', 'Albumin']])
print('Hasil dari target value data hepatitis adalah :', target_value)
print('Hasil dari regresi data hepatitis yang diambil kolom tertentu adalah :\n', data_hepatitis.loc[mask, target_column])
# Out:
# Hasil data hepatitis mean
#        Age  Bilirubin  Alk Phosphate   SGOT  Albumin  Protime
# 6    34.0        0.9           95.0   28.0      4.0     75.0
# 11   39.0        1.3           78.0   30.0      4.4     85.0
# 12   32.0        1.0           59.0  249.0      3.7     54.0
# 13   41.0        0.9           81.0   60.0      3.9     52.0
# 14   30.0        2.2           57.0  144.0      4.9     78.0
# ..    ...        ...            ...    ...      ...      ...
# 140  45.0        1.3           85.0   44.0      4.2     85.0
# 144  49.0        1.4           85.0   70.0      3.5     35.0
# 146  31.0        1.2           75.0  173.0      4.2     54.0
# 154  53.0        1.5           81.0   19.0      4.1     48.0
# 155  43.0        1.2          100.0   19.0      3.1     42.0
#
# [80 rows x 6 columns]
#
# Hasil data hepatitis median
#        Age  Bilirubin  Alk Phosphate   SGOT  Albumin  Protime
# 6    34.0        0.9           95.0   28.0      4.0     75.0
# ...

# %% [markdown]
# # Tabel no 4

# %%
#mengimport library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#memuat data
data_bank = pd.read_csv('ATM-Transaction.csv')
data_bank
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1/1/2011                 50
# 1          Mount Road ATM         1/1/2011                253
# 2             Airport ATM         1/1/2011                 98
# 3            KK Nagar ATM         1/1/2011                265
# 4      Christ College ATM         1/1/2011                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM         29/09/17                137
# 11585      Mount Road ATM         29/09/17                 79
# 11586         Airport ATM         29/09/17                117
# 11587        KK Nagar ATM         29/09/17                 76
# 11588  Christ College ATM         29/09/17                143
#
#        Total amount Withdrawn (Rupee)  Total amount Withdrawn (Rupiah)  \
# 0                              123800                         23136982
# 1                              767900                        143512831
# ...

# %% [markdown]
# # Deteksi Outlier: InterQuartile Range dan BoxPlot

# %% [markdown]
# Bank mana yang teramai dan tersepi bagi nasabah untuk melakukan penarikan uang?

# %%
# hitung transaksi setiap bank
gabungan_data_bank = data_bank.groupby('ATM Name')[['Total amount Withdrawn (Rupee)', 'Total amount Withdrawn (Rupiah)']].sum()
print('Hasil gabungan data bank\n', gabungan_data_bank) 

# tampilkan bank teramai
transaksi_bank_teramai = gabungan_data_bank[['Total amount Withdrawn (Rupee)', 'Total amount Withdrawn (Rupiah)']].idxmax()
print('\nBank mana yang teramai bagi nasabah untuk melakukan penarikan uang adalah :')
print(transaksi_bank_teramai)

# tampilkan bank tersepi
transaksi_bank_tersepi = gabungan_data_bank[['Total amount Withdrawn (Rupee)', 'Total amount Withdrawn (Rupiah)']].idxmin()
print('Bank mana yang tersepi bagi nasabah untuk melakukan penarikan uang adalah :')
print(transaksi_bank_tersepi)
# Out:
# Hasil gabungan data bank
#                      Total amount Withdrawn (Rupee)  \
# ATM Name
# Airport ATM                              999511100
# Big Street ATM                           726419500
# Christ College ATM                      1311309000
# KK Nagar ATM                            1854299300
# Mount Road ATM                          1161463900
#
#                     Total amount Withdrawn (Rupiah)
# ATM Name
# Airport ATM                            186798629479
# Big Street ATM                         135760540355
# Christ College ATM                     245070539010
# KK Nagar ATM                           346549996177
# Mount Road ATM                         217065988271
#
# Bank mana yang teramai bagi nasabah untuk melakukan penarikan uang adalah :
# Total amount Withdrawn (Rupee)     KK Nagar ATM
# Total amount Withdrawn (Rupiah)    KK Nagar ATM
# dtype: object
# Bank mana yang tersepi bagi nasabah untuk melakukan penarikan uang adalah :
# ...

# %% [markdown]
# Pada hari apa ATM paling sering dan pada hari apa yang paling jarang dikunjungi oleh nasabah untuk melakukan penarikan uang?

# %%
# memilih kolom numerik
kolom_numerik = data_bank.select_dtypes(include = [np.number])

# hitung jumlah transaksi penarikan uang setiap hari
data_bank_hari_kerja = kolom_numerik.groupby(data_bank['Weekday']).sum()
print('Hasil dari transaksi penarikan uang setiap hari\n',data_bank_hari_kerja)

# tampilkan hari yang sering dikunjungi
data_bank_sering_dikunjungi = data_bank['Weekday'].value_counts().idxmax()
print('\nHasil hari yang sering dikunjungi oleh nasabah adalah :',data_bank_sering_dikunjungi)

# tampilkan hari yang jarang dikunjungi
data_bank_jarang_dikunjungi = data_bank['Weekday'].value_counts().idxmin()
print('Hasil hari yang jarang dikunjungi oleh nasabah adalah :', data_bank_jarang_dikunjungi)
# Out:
# Hasil dari transaksi penarikan uang setiap hari
#             No Of Withdrawals  Total amount Withdrawn (Rupee)  \
# Weekday
# FRIDAY                111947                       492418500
# Friday                 55516                       221085100
# MONDAY                122188                       547007500
# Monday                 59798                       249967900
# SATURDAY              159142                       702160900
# SUNDAY                260307                      1009695500
# Saturday               65563                       270863000
# Sunday                 50997                       173463300
# THURSDAY              115698                       522969200
# TUESDAY               126333                       556597100
# Thursday               59072                       245092300
# Tuesday                59382                       244461300
# WEDNESDAY             122740                       559273700
# ...

# %% [markdown]
# Lakukan deteksi outlier untuk melihat potensi adanya fraud berdasarkan atribut Total amount Withdrawn (in Rupiah) pada dataset ATM Transaction menggunakan metode InterQuartileRange dan visualisasikan menggunakan BoxPlot serta sebutkan nama No Of Withdrawals dan nama ATM-nya yang terdeteksi fraud.

# %%
# Hitung IQR Total amount Withdrawn (Rupiah)
Q1 = data_bank['Total amount Withdrawn (Rupiah)'].quantile(0.25)
Q3 = data_bank['Total amount Withdrawn (Rupiah)'].quantile(0.75)
IQR = Q3 - Q1
print('Hasil dari IQR total amount Withdrawn (Rupiah) adalah :', IQR)

# Hitung batas atas dan bawah
batas_atas = data_bank['Total amount Withdrawn (Rupiah)'].quantile(0.75) + 1.5 * IQR
print('Hasil dari batas atas Total amount Withdrawn (Rupiah) adalah :', batas_atas)
batas_bawah = data_bank['Total amount Withdrawn (Rupiah)'].quantile(0.25) - 1.5 * IQR
print('Hasil dari batas atas Total amount Withdrawn (Rupiah) adalah :', batas_bawah)

# outlier 
outlier_penarikan_uang_rupiah = data_bank[(data_bank['Total amount Withdrawn (Rupiah)'] < batas_bawah) 
                                | (data_bank['Total amount Withdrawn (Rupiah)'] > batas_atas)]
print('\nHasil dari outlier Total amount Withdrawn (Rupiah) adalah :\n', outlier_penarikan_uang_rupiah)

# boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(data_bank['Total amount Withdrawn (Rupiah)'], vert = False)
plt.title('Box Plot dari Total amount Withdrawn (Rupiah)')
plt.show()

#sebutkan nama No Of Withdrawals dan nama ATM-nya yang terdeteksi fraud.
print('Data yang terdeteksi sebagai outlier :\n', outlier_penarikan_uang_rupiah[['No Of Withdrawals', 'ATM Name']])
# Out:
# Hasil dari IQR total amount Withdrawn (Rupiah) adalah : 68383051.0
# Hasil dari batas atas Total amount Withdrawn (Rupiah) adalah : 228089900.5
# Hasil dari batas atas Total amount Withdrawn (Rupiah) adalah : -45442303.5
#
# Hasil dari outlier Total amount Withdrawn (Rupiah) adalah :
#                   ATM Name Transaction Date  No Of Withdrawals  \
# 13           KK Nagar ATM         3/1/2011                309
# 153          KK Nagar ATM         31/01/11                302
# 338          KK Nagar ATM         9/3/2011                286
# 608          KK Nagar ATM         2/5/2011                244
# 758          KK Nagar ATM         1/6/2011                252
# ...                   ...              ...                ...
# 11469  Christ College ATM         5/9/2017                222
# 11474  Christ College ATM         6/9/2017                244
# 11479  Christ College ATM         7/9/2017                261
# 11499  Christ College ATM        11/9/2017                251
# ...
